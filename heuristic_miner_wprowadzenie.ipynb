# %%
from BP_mining.heuristic_miner import HeuristicMiner

# %%
log_file_path = "./sample_logs/heuristic_log.xes"

# %%
heuristic = HeuristicMiner(log_file_path)

# %% [markdown]
# ### Logi z wykladu

# %%
heuristic.log.to_list()
# Out:
# ['abdcfgfh', 'abdcfh', 'abbcdfgfh', 'abbdcfgfh', 'abcdeh', 'abbcdeh']

# %% [markdown]
# ### Jedna metoda odpala wszystko:

# %%
heuristic.execute_algorithm()

# %% [markdown]
# ### Po kolei

# %%
heuristic.set_relation_frequency_matrix()
heuristic.get_relation_frequency_matrix(normalized=False)
# Out:
#     a    b    c    d    e    f    g    h
# a NaN  6.0  NaN  NaN  NaN  NaN  NaN  NaN
# b NaN  3.0  3.0  3.0  NaN  NaN  NaN  NaN
# c NaN  NaN  NaN  3.0  NaN  3.0  NaN  NaN
# d NaN  NaN  3.0  NaN  2.0  1.0  NaN  NaN
# e NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.0
# f NaN  NaN  NaN  NaN  NaN  NaN  3.0  4.0
# g NaN  NaN  NaN  NaN  NaN  3.0  NaN  NaN
# h NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
from IPython.display import display

heuristic.set_2loop_frequency_matrix()
print("Metoda get do tabeli 2loop zwraca: ")
display(heuristic.get_2loop_frequency_matrix(normalized=False))
print("\n---------\n")
print("Ale atyrybut 2loop matrix ma takie indeksy, bo prosciej: ")
display(heuristic.rel_2loop_frequency_df)
# Out:
# Metoda get do tabeli 2loop zwraca:
#       a   b   c   d   e   f    g   h
# a_a NaN NaN NaN NaN NaN NaN  NaN NaN
# b_b NaN NaN NaN NaN NaN NaN  NaN NaN
# c_c NaN NaN NaN NaN NaN NaN  NaN NaN
# d_d NaN NaN NaN NaN NaN NaN  NaN NaN
# e_e NaN NaN NaN NaN NaN NaN  NaN NaN
# f_f NaN NaN NaN NaN NaN NaN  3.0 NaN
# g_g NaN NaN NaN NaN NaN NaN  NaN NaN
# h_h NaN NaN NaN NaN NaN NaN  NaN NaN
# ---------
#
# Ale atyrybut 2loop matrix ma takie indeksy, bo prosciej:
#     a   b   c   d   e   f    g   h
# a NaN NaN NaN NaN NaN NaN  NaN NaN
# b NaN NaN NaN NaN NaN NaN  NaN NaN
# c NaN NaN NaN NaN NaN NaN  NaN NaN
# d NaN NaN NaN NaN NaN NaN  NaN NaN
# e NaN NaN NaN NaN NaN NaN  NaN NaN
# f NaN NaN NaN NaN NaN NaN  3.0 NaN
# g NaN NaN NaN NaN NaN NaN  NaN NaN
# h NaN NaN NaN NaN NaN NaN  NaN NaN

# %% [markdown]
# # Po normalizacji

# %%
heuristic.normalize_relation_frequency_matrix()
heuristic.get_relation_frequency_matrix()
# Out:
#     a         b     c     d         e     f    g         h
# a NaN  0.857143   NaN   NaN       NaN   NaN  NaN       NaN
# b NaN  0.750000  0.75  0.75       NaN   NaN  NaN       NaN
# c NaN       NaN   NaN  0.00       NaN  0.75  NaN       NaN
# d NaN       NaN  0.00   NaN  0.666667  0.50  NaN       NaN
# e NaN       NaN   NaN   NaN       NaN   NaN  NaN  0.666667
# f NaN       NaN   NaN   NaN       NaN   NaN  0.0  0.800000
# g NaN       NaN   NaN   NaN       NaN  0.00  NaN       NaN
# h NaN       NaN   NaN   NaN       NaN   NaN  NaN       NaN

# %%
heuristic.normalize_2loop_frequency_matrix()
heuristic.get_2loop_frequency_matrix()
# Out:
#       a   b   c   d   e   f     g   h
# a_a NaN NaN NaN NaN NaN NaN   NaN NaN
# b_b NaN NaN NaN NaN NaN NaN   NaN NaN
# c_c NaN NaN NaN NaN NaN NaN   NaN NaN
# d_d NaN NaN NaN NaN NaN NaN   NaN NaN
# e_e NaN NaN NaN NaN NaN NaN   NaN NaN
# f_f NaN NaN NaN NaN NaN NaN  0.75 NaN
# g_g NaN NaN NaN NaN NaN NaN   NaN NaN
# h_h NaN NaN NaN NaN NaN NaN   NaN NaN
